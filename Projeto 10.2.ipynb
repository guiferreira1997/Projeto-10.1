# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
previsao_renda = pd.read_csv('Profissao-Cientista_de_Dados_M10_support material.csv')
previsao_renda.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
sns.pointplot(data=previsao_renda, x='posse_de_imovel', y='renda', dodge=True, ci=90)
# Out:
# C:\Users\guife\AppData\Local\Temp\ipykernel_1020\3009507880.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.pointplot(data=previsao_renda, x='posse_de_imovel', y='renda', dodge=True, ci=90)
# <Axes: xlabel='posse_de_imovel', ylabel='renda'>

# %%
sns.pointplot(data=previsao_renda, x='posse_de_veiculo', y='renda', dodge=True, ci=90)
# Out:
# C:\Users\guife\AppData\Local\Temp\ipykernel_1020\1004846271.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.pointplot(data=previsao_renda, x='posse_de_veiculo', y='renda', dodge=True, ci=90)
# <Axes: xlabel='posse_de_veiculo', ylabel='renda'>

# %%
sns.pointplot(x="posse_de_veiculo", y="posse_de_imovel",data=previsao_renda, dodge=True, ci = 90)
# Out:
# C:\Users\guife\AppData\Local\Temp\ipykernel_1020\2162108281.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.pointplot(x="posse_de_veiculo", y="posse_de_imovel",data=previsao_renda, dodge=True, ci = 90)
# <Axes: xlabel='posse_de_veiculo', ylabel='posse_de_imovel'>

# %%
# Podemos notar que com a renda mais elevada é possível que tenha posse de veiculo, ou imovel. Os dois são bem parecidos.
